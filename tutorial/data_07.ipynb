# %%
import pandas as pd
df = pd.read_pickle("data/df_201704health.pickle")
df["摂取カロリー"] = df["摂取カロリー"].astype("float")
df.head()
# Out:
#                歩数  摂取カロリー   歩数/カロリー 運動指数
# date
# 2017-04-01   5439  2500.0  2.175600  Low
# 2017-04-02   2510  2300.0  1.091304  Low
# 2017-04-03  10238  1950.0  5.250256  Mid
# 2017-04-04   8209  1850.0  4.437297  Mid
# 2017-04-05   9434  1930.0  4.888083  Mid

# %%
df.loc[:,"摂取カロリー"].max()
# Out:
# 2500.0

# %%
df.loc[:,"摂取カロリー"].min()
# Out:
# 1800.0

# %%
df.loc[:,"摂取カロリー"].mode() #最頻値
# Out:
# 0    2300.0
# dtype: float64

# %%
df.loc[:,"摂取カロリー"].mean() #平均値

# %%
df.loc[:,"摂取カロリー"].median() #中央値
# Out:
# 1945.0

# %%
df.loc[:,"摂取カロリー"].std() #標本標準偏差
#(((X - X.mean())**2).sum()/(len(X)-1))**(1/2) X=df.loc[:,"摂取カロリー"]
# Out:
# 205.54944590692452

# %%
df.loc[:,"摂取カロリー"].std(ddof=0) #母標準偏差
#(((X - X.mean())**2).mean())**(1/2) X=df.loc[:,"摂取カロリー"]
# Out:
# 202.09458731549992

# %%
df[df.loc[:,"摂取カロリー"]==2300].count()
# Out:
# 歩数         8
# 摂取カロリー     8
# 歩数/カロリー    8
# 運動指数       8
# dtype: int64

# %% [markdown]
# df.describe()

# %%
df.corr()
# Out:
#                歩数    摂取カロリー   歩数/カロリー
# 歩数       1.000000 -0.498703  0.982828
# 摂取カロリー  -0.498703  1.000000 -0.636438
# 歩数/カロリー  0.982828 -0.636438  1.000000

# %%
# %matplotlib inline

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(df)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f9ead0561f0>,
# ...
#       dtype=object)

# %%
df.loc[:,["摂取カロリー", "歩数"]].values
# Out:
# array([[ 2500.,  5439.],
#        [ 2300.,  2510.],
#        [ 1950., 10238.],
#        [ 1850.,  8209.],
#        [ 1930.,  9434.],
#        [ 1800.,  7593.],
#        [ 1940.,  9320.],
#        [ 2300.,  4873.],
#        [ 1950., 12045.],
#        [ 1850.,  7493.],
#        [ 1930.,  7289.],
#        [ 2300.,  6481.],
#        [ 1800., 10287.],
#        [ 1940.,  8043.],
#        [ 2300.,  7435.],
#        [ 2300.,  7529.],
#        [ 1940.,  8031.],
#        [ 2300.,  8475.],
#        [ 1950.,  8132.],
#        [ 1800., 15328.],
#        [ 1940., 12849.],
#        [ 2300.,  4029.],
#        [ 1950.,  3890.],
#        [ 1850.,  8093.],
#        [ 1950.,  7823.],
#        [ 1850.,  7492.],
#        [ 1930.,  7203.],
#        [ 1850.,  7302.],
#        [ 2300.,  6033.],
#        [ 1950.,  4093.]])
